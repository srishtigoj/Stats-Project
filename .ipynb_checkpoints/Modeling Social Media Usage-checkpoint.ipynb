# %% [markdown]
# # COMPSS 212: Final Group Project
# ## Why do you waste so much time on social media?
#
# #### by Alex Liu, Shaily Bajracharya, and Srishti Gojamgunde

# %% [markdown]
# ### Background (I'm writing this at 3 am so it doesn't sound very smart, we can fix it later...)
#
# In recent years, social media usage has been found to predict individual and societal outcomes such as social anxiety, depressive symptoms, dissociative symptoms, low self-esteem, health risk behaviors, addictive behavior, insomnia, political polarization, misinformation, cultural homogenization, environmental impacts, etc.(Arguedas et al., 2022, Baughan et al., 2022; Cunningham et al., 2021; González-Bueso et al., 2018; McCabe et al., 2024; Moon and Lewis., 2024, Purba et al., 2023; Valkenburg et al., 2021; Walkley, 2023).

# %% [markdown]
# The list of negative consequences of social media seems to be endless, but there is a surprising dearth of research on the factors that actually predict social media usage.
#
# ### Potential factors predicting social media usage:
# Through our research we have identified the following relationships as having some support from academic literature:
# * Age and gender affect the social media platform of choice: younger adults are more active on platforms like Instagram, Snapchat, and TikTok, and women tend to use platforms such as Instagram, Facebook, and TikTok more than men who are more active on platforms like Reddit and X (formerly Twitter) (Pew Research Center, 2024; Vaid and Harari, 2020).
# *  Age also impacts a person's financial stability, and financial stability (specifically, high household income) has been associated with increased social media usage (Hruska and Maresova, 2020).
# *  Gender impacts profession (MacDonald et al., 2023) and profession at least partly determines financial situation which, in turn, is associated with increased social media usage.
# *  Rural populations use social media, and the internet in general, less than urban populations (Hale et al., 2010). People living in rural areas are also more likely to own property, but the median income levels are lower than in comparable urban locations (Copeland, 2022).
# *  Self-reported levels of productivity, lower measures of restraint and self-control, and greater addiction level all predict significant increases in social media usage and there is also evidence for social media to exacerbate all of them(Li et al., 2021; Peng and Liao, 2023).
# *  One might expect to see some differences in social media usage based on device type (phones provide ease of accessibility while travelling or lying in bed whereas computers do not), OS, and connection type (we can intuit reduced usage when users are using their personal mobile network vs public WiFi).
# * Self-Reported measures like reason for consuming content on social media may affect usage especially because social media becomes a tool for procrastination (Alblwi et al., 2021).

# %% [markdown]
# ### Loading required libraries:

# %%
install.packages("ggdag", lib = "/srv/r")
install.packages("GGally", lib = "/srv/r")
install.packages("car", lib = "/srv/r")
install.packages("skedastic",lib = "/srv/r")
install.packages("boot",lib = "/srv/r")
# Out:
# also installing the dependencies ‘V8’, ‘dagitty’
#
#
# also installing the dependencies ‘patchwork’, ‘ggstats’
#
#
# also installing the dependencies ‘RcppGSL’, ‘rbibutils’, ‘kimisc’, ‘RcppZiggurat’, ‘RcppParallel’, ‘Rdpack’, ‘pracma’, ‘CompQuadForm’, ‘bazar’, ‘quadprog’, ‘inflection’, ‘Rfast’, ‘quadprogXT’, ‘ROI’, ‘osqp’, ‘ROI.plugin.qpoases’

# %%
library(tidyverse)
library(dplyr)
library(ggplot2)
library(ggdag)
library(gridExtra)
library(GGally)
library(car)
library(psych)
library(skedastic)
library(lmtest)
library(boot)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.5.1     ✔ purrr   1.0.2
# ✔ tibble  3.2.1     ✔ dplyr   1.1.4
# ✔ tidyr   1.3.1     ✔ stringr 1.5.1
# ✔ readr   2.1.5     ✔ forcats 1.0.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘ggdag’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# The following object is masked from ‘package:purrr’:
#
#     some
#
#
#
# Attaching package: ‘psych’
#
#
# The following object is masked from ‘package:car’:
#
#     logit
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha
#
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#
# Attaching package: ‘boot’
#
#
# The following object is masked from ‘package:psych’:
#
#     logit
#
#
# The following object is masked from ‘package:car’:
#
#     logit

# %%
tidy_ggdag <- dagify(
  SM ~ R_U + Fin + X + D +Age + R + Act,
  SM ~ ~A, 
  SM ~ ~C,
  SM ~ ~P,
  Fin ~ Age + Job + R_U,
  X ~ Age + M_F,
  Job ~ M_F,
  P ~Job,
  exposure = "X",
  outcome = "SM"
) %>%
  tidy_dagitty()

tidy_ggdag
# Out:
# # A DAG with 13 nodes and 17 edges
# #
# # Exposure: X
# # Outcome: SM
# #
# # A tibble: 18 × 8
#    name       x      y direction to      xend   yend circular
#    <chr>  <dbl>  <dbl> <fct>     <chr>  <dbl>  <dbl> <lgl>
#  1 A      0.382 -3.74  <->       SM    -0.166 -2.01  FALSE
#  2 Act   -0.764 -3.77  ->        SM    -0.166 -2.01  FALSE
#  3 Age    0.590 -0.457 ->        Fin    0.958 -1.30  FALSE
#  4 Age    0.590 -0.457 ->        SM    -0.166 -2.01  FALSE
#  5 Age    0.590 -0.457 ->        X      1.60  -0.628 FALSE
#  6 C     -2.03  -2.05  <->       SM    -0.166 -2.01  FALSE
#  7 D     -1.72  -0.913 ->        SM    -0.166 -2.01  FALSE
#  8 Fin    0.958 -1.30  ->        SM    -0.166 -2.01  FALSE
#  9 Job    2.61  -1.58  ->        Fin    0.958 -1.30  FALSE
# 10 Job    2.61  -1.58  ->        P      1.65  -2.54  FALSE
# 11 M_F    3.20  -0.426 ->        Job    2.61  -1.58  FALSE
# 12 M_F    3.20  -0.426 ->        X      1.60  -0.628 FALSE
# 13 P      1.65  -2.54  <->       SM    -0.166 -2.01  FALSE
# 14 R     -1.65  -3.10  ->        SM    -0.166 -2.01  FALSE
# 15 R_U   -0.311 -0.740 ->        Fin    0.958 -1.30  FALSE
# 16 R_U   -0.311 -0.740 ->        SM    -0.166 -2.01  FALSE
# 17 SM    -0.166 -2.01  NA        NA    NA     NA     FALSE
# 18 X      1.60  -0.628 ->        SM    -0.166 -2.01  FALSE

# %%
tidy_ggdag %>%
  ggdag() +
  theme(
    plot.margin = unit(c(1, 1, 1, 1), "cm"),
    axis.text = element_text(size = 20)      # Adjust text size
  )
# Out:
# plot without title

# %% [markdown]
# #### Insights from the DAG:
# * Demographics i.e. rural vs urban may affect both Social Media Usage as well as overall Financial Status (which is causally linked to Social Media Usage). Thus, there is a backdoor path created. We can block this backdoor path by controlling for Demographics since the backdoor criterion is met: All backdoor paths are blocked and no element of Demographics is a collider.
# * Age is also a confounder as it affects Financial Status, Platform, and Social Media Usage (Younger people are more likely to be active on social media).
# * Financial Status arises a collider as it descends from Job, Age, and Demographics. We will explicitly avoid controlling for Financial Status to prevent collider bias.

# %%
#Loading the dataset
url <- "https://raw.githubusercontent.com/srishtigoj/Stats-Project/refs/heads/main/Time-Wasters%20on%20Social%20Media%202.csv"
data <- read.csv(url)
head(data)
# Out:
#   UserID Age Gender Location      Income Debt  Owns.Property Profession
# 1 1      56  Male   Pakistan      82812   TRUE  TRUE         Engineer
# 2 2      46  Female Mexico        27999  FALSE  TRUE         Artist
# 3 3      32  Female United States 42436  FALSE  TRUE         Engineer
# 4 4      60  Male   Barzil        62963   TRUE FALSE         Waiting staff
# 5 5      25  Male   Pakistan      22096  FALSE  TRUE         Manager
# 6 6      38  Male   Vietnam       45279  FALSE FALSE         driver
#   Demographics Platform  ⋯ ProductivityLoss Satisfaction Watch.Reason
# 1 Rural        Instagram ⋯ 3                7            Procrastination
# 2 Urban        Instagram ⋯ 5                5            Habit
# 3 Rural        Facebook  ⋯ 6                4            Entertainment
# 4 Rural        YouTube   ⋯ 3                7            Habit
# 5 Urban        TikTok    ⋯ 8                2            Boredom
# 6 Urban        Instagram ⋯ 3                7            Entertainment
#   DeviceType OS      Watch.Time Self.Control Addiction.Level CurrentActivity
# 1 Smartphone Android 9:00 PM     5           5               Commuting
# 2 Computer   Android 5:00 PM     7           3               At school
# 3 Tablet     Android 2:00 PM     8           2               At home
# 4 Smartphone Android 9:00 PM     5           5               Commuting
# 5 Smartphone iOS     8:00 AM    10           0               At home
# 6 Computer   Android 9:00 PM     5           5               At home
#   ConnectionType
# 1 Mobile Data
# 2 Wi-Fi
# 3 Mobile Data
# 4 Mobile Data
# 5 Mobile Data
# 6 Wi-Fi

# %% [markdown]
# This dataset is acquired from Kaggle, posted by user 'Shahzad Aslam' and is:
# "Generated through advanced synthetic data techniques using tools like NumPy and pandas, this dataset mimics real-world social media usage scenarios. Despite being artificially created, it accurately reflects genuine usage trends..."
# There is no more information about how the data is simulated, and how it reflects real user trends, and so, we will be careful in our interpretation of any findings.

# %%
categorical <- names(data)[sapply(data, function(x) is.character(x) | is.factor(x))]
print("Categorical columns:")
print(categorical)
# Out:
# [1] "Categorical columns:"
#  [1] "Gender"          "Location"        "Profession"      "Demographics"
#  [5] "Platform"        "Video.Category"  "Frequency"       "Watch.Reason"
#  [9] "DeviceType"      "OS"              "Watch.Time"      "CurrentActivity"
# [13] "ConnectionType"

# %%
for(col in categorical) {
    cat("\nUnique values in", col, ":", length(unique(data[[col]])), "values\n")
    print(unique(data[[col]]))
}
# Out:
# Unique values in Gender : 3 values
# [1] "Male"   "Female" "Other"
#
# Unique values in Location : 10 values
#  [1] "Pakistan"      "Mexico"        "United States" "Barzil"
#  [5] "Vietnam"       "India"         "Indonesia"     "Philippines"
#  [9] "Japan"         "Germany"
#
# Unique values in Profession : 9 values
# [1] "Engineer"      "Artist"        "Waiting staff" "Manager"
# [5] "driver"        "Students"      "Labor/Worker"  "Cashier"
# [9] "Teacher"
#
# Unique values in Demographics : 2 values
# [1] "Rural" "Urban"
#
# Unique values in Platform : 4 values
# [1] "Instagram" "Facebook"  "YouTube"   "TikTok"
#
# Unique values in Video.Category : 9 values
# [1] "Pranks"        "Vlogs"         "Gaming"        "Jokes/Memes"
# [5] "Entertainment" "ASMR"          "Life Hacks"    "Trends"
# [9] "Comedy"
#
# Unique values in Frequency : 4 values
# [1] "Night"     "Afternoon" "Evening"   "Morning"
#
# Unique values in Watch.Reason : 4 values
# [1] "Procrastination" "Habit"           "Entertainment"   "Boredom"
#
# Unique values in DeviceType : 3 values
# [1] "Smartphone" "Computer"   "Tablet"
#
# Unique values in OS : 4 values
# [1] "Android" "iOS"     "MacOS"   "Windows"
#
# Unique values in Watch.Time : 16 values
#  [1] "9:00 PM"  "5:00 PM"  "2:00 PM"  "8:00 AM"  "8:30 PM"  "3:45 PM"
#  [7] "6:05 PM"  "9:15 AM"  "7:45 AM"  "7:25 PM"  "3:55 PM"  "11:30 PM"
# [13] "10:15 PM" "9:55 AM"  "4:25 PM"  "5:45 PM"
#
# Unique values in CurrentActivity : 4 values
# [1] "Commuting" "At school" "At home"   "At work"
#
# Unique values in ConnectionType : 2 values
# [1] "Mobile Data" "Wi-Fi"

# %%
#Counting occurences of categorical variables and visualizing the distributions
blue_palette <- c("#5b84b1","#89c2d9","#d4f1f9","#4a47a3","#8e7cc3","#bcb7e3","#e1bee7","#f2d7ee","#c94c4c","#e28e8e", "#f7d6d6","#843b62", "#ba6f95", "#f2c9d1", "#9b5de5", "#c780e8")

for (column in categorical) {
  counts <- as.data.frame(table(data[[column]]))
  colnames(counts) <- c("Category", "Count")
  
  plot <- ggplot(counts, aes(x = Category, y = Count, fill = Category)) +
    geom_bar(stat = "identity") +
    labs(title = paste("Distribution of", column),
         x = column,
         y = "Count") +
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    guides(fill = FALSE) +
    scale_fill_manual(values = blue_palette) 
  
  print(plot)  # Display the plot
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# Here, we can see that certain categories have overrepresented groups, however, if the overrepresentation reflects the actual population distribution, it may not need correction. For instance, India and United States are two overrepresented locations but these two countries have the largest number of social media users in real life (excluding China) and thus, we can allow the skewed distribution in our data.
#
# The only category we might want to correct is 'Demographics' are Rural demographics are more frequently appreading in the data. Both upsampling and downsampling overrepresented groups has its limitations (discarding data and overfitting respectively). Thus, we will be using **bootstrapping** to repeatedly sample from the data, ensuring that the results are robust despite overrepresentation.

# %% [markdown]
# ### Choice of Variables

# %% [markdown]
# Based on background research as well as initial data exploration we choose the following predictors to model Social Media Usage:
# * Income,
# * Debt
# * Property ownership
# * Device Type
# * Platform
#
# while controlling for:
# * Demographics (Urban/Rural)
# * Age
#
# Outcome Variables:
# * Total Time Spent
# * Number of Sessions

# %% [markdown]
# ## Research Question and Hypothesis

# %% [markdown]
# Question: To what extent do individual characteristics like financial status, rural/urban demographics, age, and choice of device and social media platform predict social media usage as measured by Total Time Spent and Number of Sessions?
#
# Null Hypothesis: Controlling for all other IVs, none of the predictors are significant in predicting social media usage.
#
# H0: Bj = 0
#
# Alternative Hypothesis: Controlling for all other IVs, at least one of the predictors are significant in predicting social media usage.
#
# HA: Bj ≠ 0

# %%
set.seed(212)

bootstrap_data <- function(data, n_samples = 100, sample_size = NULL, seed = NULL) {
  if (!is.null(seed)) {
    set.seed(seed)
  }
  
  sample_size <- ifelse(is.null(sample_size), nrow(data), sample_size)
  bootstrapped_samples <- lapply(1:n_samples, function(i) {
    data[sample(1:nrow(data), sample_size, replace = TRUE), ]
  })
  
  return(bootstrapped_samples)
}

bootstrapped_samples <- bootstrap_data(data, n_samples = 100, seed = 212)

combined_bootstrapped_data <- do.call(rbind, bootstrapped_samples)

write.csv(combined_bootstrapped_data, "bootstrapped_data.csv", row.names = FALSE)

print(paste("Generated", length(bootstrapped_samples), "bootstrapped samples."))
# Out:
# [1] "Generated 100 bootstrapped samples."

# %%
bootstrapped_data <- read_csv("bootstrapped_data.csv")
# Out:
# Rows: 100000 Columns: 36
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (12): Gender, Location, Profession, Demographics, Platform, Video.Categ...
# dbl  (21): UserID, Age, Income, Total.Time.Spent, Number.of.Sessions, Video....
# lgl   (2): Debt, Owns.Property
# time  (1): Watch.Time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ### Modeling Social Media Usage by Total Time Spent

# %%
ols_model_1 <- lm(Total.Time.Spent ~ 
                Income + Debt + Owns.Property + DeviceType + Platform + Demographics + Age + Gender + Profession 
                + Profession*Gender + Profession*Income + Age*Income + Demographics*Income + Profession*Debt + Age*Debt + Demographics*Debt + Profession*Owns.Property + 
                Age*Owns.Property + Demographics*Owns.Property + Gender*Platform + Age*Platform
                ,data=bootstrapped_data)
summary(ols_model_1)
# Out:
# Call:
# lm(formula = Total.Time.Spent ~ Income + Debt + Owns.Property +
#     DeviceType + Platform + Demographics + Age + Gender + Profession +
#     Profession * Gender + Profession * Income + Age * Income +
#     Demographics * Income + Profession * Debt + Age * Debt +
#     Demographics * Debt + Profession * Owns.Property + Age *
#     Owns.Property + Demographics * Owns.Property + Gender * Platform +
#     Age * Platform, data = bootstrapped_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -188.628  -66.816   -0.561   67.689  201.265
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                               -3.100e+00  5.223e+00  -0.594
# Income                                     2.676e-03  1.197e-04  22.364
# DebtTRUE                                  -6.750e+01  5.533e+00 -12.199
# Owns.PropertyTRUE                          5.196e+01  3.115e+00  16.682
# DeviceTypeSmartphone                       4.070e+00  8.107e-01   5.020
# DeviceTypeTablet                          -9.563e-01  8.795e-01  -1.087
# PlatformInstagram                         -8.339e+00  2.699e+00  -3.090
# PlatformTikTok                             1.376e+01  2.655e+00   5.182
# PlatformYouTube                           -6.985e+00  2.669e+00  -2.617
# DemographicsUrban                          3.267e+00  2.034e+00   1.606
# Age                                        1.452e+00  7.706e-02  18.847
# GenderMale                                 2.285e+01  2.998e+00   7.621
# GenderOther                                2.046e+01  3.963e+00   5.162
# ProfessionCashier                          1.173e+02  5.677e+00  20.661
# Professiondriver                           1.121e+02  4.672e+00  23.995
# ProfessionEngineer                         1.726e+01  5.816e+00   2.967
# ProfessionLabor/Worker                     9.604e+01  4.446e+00  21.603
# ProfessionManager                          4.302e+01  6.007e+00   7.161
# ProfessionStudents                         9.631e+01  4.364e+00  22.072
# ProfessionTeacher                          2.842e+01  6.855e+00   4.145
# ProfessionWaiting staff                    9.368e+01  4.414e+00  21.224
# GenderMale:ProfessionCashier               2.754e+01  3.742e+00   7.360
# GenderOther:ProfessionCashier              7.309e+01  4.853e+00  15.062
# GenderMale:Professiondriver               -9.701e+00  3.234e+00  -3.000
# GenderOther:Professiondriver              -4.657e+01  4.228e+00 -11.016
# GenderMale:ProfessionEngineer              1.201e+01  3.538e+00   3.394
# GenderOther:ProfessionEngineer            -3.120e+01  5.178e+00  -6.026
# GenderMale:ProfessionLabor/Worker         -2.086e+00  3.041e+00  -0.686
# GenderOther:ProfessionLabor/Worker        -2.076e+01  3.971e+00  -5.228
# GenderMale:ProfessionManager              -3.537e+01  4.043e+00  -8.748
# GenderOther:ProfessionManager             -8.389e+01  5.025e+00 -16.694
# GenderMale:ProfessionStudents             -1.751e+01  2.981e+00  -5.874
# GenderOther:ProfessionStudents            -3.906e+01  3.951e+00  -9.885
# GenderMale:ProfessionTeacher              -6.357e+01  4.013e+00 -15.841
# GenderOther:ProfessionTeacher             -5.871e+01  5.161e+00 -11.376
# GenderMale:ProfessionWaiting staff        -2.665e+01  3.023e+00  -8.817
# GenderOther:ProfessionWaiting staff       -6.139e+00  3.994e+00  -1.537
# Income:ProfessionCashier                  -2.696e-03  1.387e-04 -19.442
# Income:Professiondriver                   -2.435e-03  1.161e-04 -20.966
# Income:ProfessionEngineer                 -1.474e-04  1.382e-04  -1.067
# Income:ProfessionLabor/Worker             -2.067e-03  1.120e-04 -18.466
# Income:ProfessionManager                   3.756e-05  1.417e-04   0.265
# Income:ProfessionStudents                 -1.621e-03  1.099e-04 -14.753
# Income:ProfessionTeacher                   1.118e-04  1.564e-04   0.715
# Income:ProfessionWaiting staff            -1.916e-03  1.112e-04 -17.226
# Income:Age                                -1.434e-05  1.552e-06  -9.239
# Income:DemographicsUrban                  -4.738e-04  4.896e-05  -9.677
# DebtTRUE:ProfessionCashier                 7.446e+01  6.291e+00  11.835
# DebtTRUE:Professiondriver                  8.180e+01  5.449e+00  15.011
# DebtTRUE:ProfessionEngineer                7.277e+00  6.506e+00   1.118
# DebtTRUE:ProfessionLabor/Worker            7.649e+01  5.259e+00  14.543
# DebtTRUE:ProfessionManager                 3.455e+00  7.063e+00   0.489
# DebtTRUE:ProfessionStudents                6.847e+01  5.095e+00  13.437
# DebtTRUE:ProfessionTeacher                 6.962e+00  7.462e+00   0.933
# DebtTRUE:ProfessionWaiting staff           9.369e+01  5.215e+00  17.966
# DebtTRUE:Age                              -4.202e-01  7.478e-02  -5.619
# DebtTRUE:DemographicsUrban                 8.762e-01  2.370e+00   0.370
# Owns.PropertyTRUE:ProfessionCashier       -2.904e+01  3.539e+00  -8.203
# Owns.PropertyTRUE:Professiondriver        -2.032e+01  3.032e+00  -6.702
# Owns.PropertyTRUE:ProfessionEngineer      -4.747e+01  3.358e+00 -14.139
# Owns.PropertyTRUE:ProfessionLabor/Worker  -2.526e+01  2.846e+00  -8.877
# Owns.PropertyTRUE:ProfessionManager       -3.332e+01  3.466e+00  -9.613
# Owns.PropertyTRUE:ProfessionStudents      -6.252e+01  2.787e+00 -22.429
# Owns.PropertyTRUE:ProfessionTeacher       -3.047e+01  3.886e+00  -7.841
# Owns.PropertyTRUE:ProfessionWaiting staff -5.502e+01  2.845e+00 -19.338
# Owns.PropertyTRUE:Age                     -4.968e-01  3.947e-02 -12.585
# Owns.PropertyTRUE:DemographicsUrban        2.125e+01  1.218e+00  17.443
# PlatformInstagram:GenderMale               6.973e+00  1.691e+00   4.125
# PlatformTikTok:GenderMale                 -1.765e+01  1.697e+00 -10.400
# PlatformYouTube:GenderMale                -1.202e+01  1.734e+00  -6.931
# PlatformInstagram:GenderOther              2.546e+01  2.437e+00  10.449
# PlatformTikTok:GenderOther                 1.574e+01  2.365e+00   6.655
# PlatformYouTube:GenderOther               -2.066e+00  2.396e+00  -0.862
# PlatformInstagram:Age                     -1.483e-01  5.892e-02  -2.516
# PlatformTikTok:Age                        -3.392e-01  5.605e-02  -6.051
# PlatformYouTube:Age                        2.519e-01  5.602e-02   4.496
#                                           Pr(>|t|)
# (Intercept)                               0.552779
# Income                                     < 2e-16 ***
# DebtTRUE                                   < 2e-16 ***
# Owns.PropertyTRUE                          < 2e-16 ***
# DeviceTypeSmartphone                      5.17e-07 ***
# DeviceTypeTablet                          0.276879
# PlatformInstagram                         0.002002 **
# PlatformTikTok                            2.20e-07 ***
# PlatformYouTube                           0.008866 **
# DemographicsUrban                         0.108331
# Age                                        < 2e-16 ***
# GenderMale                                2.55e-14 ***
# GenderOther                               2.45e-07 ***
# ProfessionCashier                          < 2e-16 ***
# Professiondriver                           < 2e-16 ***
# ProfessionEngineer                        0.003011 **
# ProfessionLabor/Worker                     < 2e-16 ***
# ProfessionManager                         8.04e-13 ***
# ProfessionStudents                         < 2e-16 ***
# ProfessionTeacher                         3.40e-05 ***
# ProfessionWaiting staff                    < 2e-16 ***
# GenderMale:ProfessionCashier              1.85e-13 ***
# GenderOther:ProfessionCashier              < 2e-16 ***
# GenderMale:Professiondriver               0.002704 **
# GenderOther:Professiondriver               < 2e-16 ***
# GenderMale:ProfessionEngineer             0.000689 ***
# GenderOther:ProfessionEngineer            1.69e-09 ***
# GenderMale:ProfessionLabor/Worker         0.492746
# GenderOther:ProfessionLabor/Worker        1.72e-07 ***
# GenderMale:ProfessionManager               < 2e-16 ***
# GenderOther:ProfessionManager              < 2e-16 ***
# GenderMale:ProfessionStudents             4.26e-09 ***
# GenderOther:ProfessionStudents             < 2e-16 ***
# GenderMale:ProfessionTeacher               < 2e-16 ***
# GenderOther:ProfessionTeacher              < 2e-16 ***
# GenderMale:ProfessionWaiting staff         < 2e-16 ***
# GenderOther:ProfessionWaiting staff       0.124300
# Income:ProfessionCashier                   < 2e-16 ***
# Income:Professiondriver                    < 2e-16 ***
# Income:ProfessionEngineer                 0.286009
# Income:ProfessionLabor/Worker              < 2e-16 ***
# Income:ProfessionManager                  0.790973
# Income:ProfessionStudents                  < 2e-16 ***
# Income:ProfessionTeacher                  0.474908
# Income:ProfessionWaiting staff             < 2e-16 ***
# Income:Age                                 < 2e-16 ***
# Income:DemographicsUrban                   < 2e-16 ***
# DebtTRUE:ProfessionCashier                 < 2e-16 ***
# DebtTRUE:Professiondriver                  < 2e-16 ***
# DebtTRUE:ProfessionEngineer               0.263386
# DebtTRUE:ProfessionLabor/Worker            < 2e-16 ***
# DebtTRUE:ProfessionManager                0.624781
# DebtTRUE:ProfessionStudents                < 2e-16 ***
# DebtTRUE:ProfessionTeacher                0.350829
# DebtTRUE:ProfessionWaiting staff           < 2e-16 ***
# DebtTRUE:Age                              1.93e-08 ***
# DebtTRUE:DemographicsUrban                0.711557
# Owns.PropertyTRUE:ProfessionCashier       2.36e-16 ***
# Owns.PropertyTRUE:Professiondriver        2.06e-11 ***
# Owns.PropertyTRUE:ProfessionEngineer       < 2e-16 ***
# Owns.PropertyTRUE:ProfessionLabor/Worker   < 2e-16 ***
# Owns.PropertyTRUE:ProfessionManager        < 2e-16 ***
# Owns.PropertyTRUE:ProfessionStudents       < 2e-16 ***
# Owns.PropertyTRUE:ProfessionTeacher       4.51e-15 ***
# Owns.PropertyTRUE:ProfessionWaiting staff  < 2e-16 ***
# Owns.PropertyTRUE:Age                      < 2e-16 ***
# Owns.PropertyTRUE:DemographicsUrban        < 2e-16 ***
# PlatformInstagram:GenderMale              3.72e-05 ***
# PlatformTikTok:GenderMale                  < 2e-16 ***
# PlatformYouTube:GenderMale                4.22e-12 ***
# PlatformInstagram:GenderOther              < 2e-16 ***
# PlatformTikTok:GenderOther                2.85e-11 ***
# PlatformYouTube:GenderOther               0.388576
# PlatformInstagram:Age                     0.011864 *
# PlatformTikTok:Age                        1.45e-09 ***
# PlatformYouTube:Age                       6.95e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 80.49 on 99924 degrees of freedom
# Multiple R-squared:  0.08227,	Adjusted R-squared:  0.08158
# F-statistic: 119.4 on 75 and 99924 DF,  p-value: < 2.2e-16

# %%
vif_values <- vif(ols_model_1, type = 'predictor')
print(vif_values)
# Out:
# GVIFs computed for predictors
#                       GVIF Df GVIF^(1/(2*Df))
# Income        2.736811e+14 21        2.206703
# Debt          1.223465e+17 21        2.551805
# Owns.Property 4.707965e+11 21        1.896377
# DeviceType    1.177746e+00  2        1.041748
# Platform      1.256599e+04 15        1.369746
# Demographics  5.262449e+04  7        2.173841
# Age           7.330192e+05 13        1.681053
# Gender        1.644534e+12 35        1.494565
# Profession    8.677171e+04 53        1.113239
#                                      Interacts With
# Income                Profession, Age, Demographics
# Debt                  Profession, Age, Demographics
# Owns.Property         Profession, Age, Demographics
# DeviceType                                     --
# Platform                                Gender, Age
# Demographics            Income, Debt, Owns.Property
# Age           Income, Debt, Owns.Property, Platform
# Gender                         Profession, Platform
# Profession      Gender, Income, Debt, Owns.Property
#                                                                           Other Predictors
# Income                                   Debt, Owns.Property, DeviceType, Platform, Gender
# Debt                                   Income, Owns.Property, DeviceType, Platform, Gender
# Owns.Property                                   Income, Debt, DeviceType, Platform, Gender
# DeviceType    Income, Debt, Owns.Property, Platform, Demographics, Age, Gender, Profession
# Platform                 Income, Debt, Owns.Property, DeviceType, Demographics, Profession
# Demographics                                 DeviceType, Platform, Age, Gender, Profession
# Age                                           DeviceType, Demographics, Gender, Profession
# Gender                          Income, Debt, Owns.Property, DeviceType, Demographics, Age
# Profession                                         DeviceType, Platform, Demographics, Age

# %%
#Check residuals
fitted_values_1 <- fitted(ols_model_1)
residuals_1 <- resid(ols_model_1)

plot(fitted_values_1, residuals_1,
     main = "Residuals vs Fitted Values",
     xlab = "Fitted Values",
     ylab = "Residuals",
     pch = 19, col = "blue")

abline(h = 0, col = "red", lty = 2)
# Out:
# Plot with title “Residuals vs Fitted Values”

# %%
#To check for heteroskedasticity
white_test <- white(ols_model)
white_test
# Out:
#   statistic p.value   parameter method       alternative
# 1 93.69672  0.9999078 150       White's Test greater

# %% [markdown]
# The White Test confirms that the homoskedasticity assumption is met i.e. the disturbance term is homoskedastic.

# %% [markdown]
# ### Modeling Social Media Usage by Number of Sessions/Frequency of Usage

# %%
ols_model_2 <- lm(Number.of.Sessions ~ 
                Income + Debt + Owns.Property + DeviceType + Platform + Demographics + Age + Gender + Profession 
                + Profession*Gender + Profession*Income + Age*Income + Demographics*Income + Profession*Debt + Age*Debt + Demographics*Debt + Profession*Owns.Property + 
                Age*Owns.Property + Demographics*Owns.Property + Gender*Platform + Age*Platform
                ,data=bootstrapped_data)
summary(ols_model_2)
# Out:
# Call:
# lm(formula = Number.of.Sessions ~ Income + Debt + Owns.Property +
#     DeviceType + Platform + Demographics + Age + Gender + Profession +
#     Profession * Gender + Profession * Income + Age * Income +
#     Demographics * Income + Profession * Debt + Age * Debt +
#     Demographics * Debt + Profession * Owns.Property + Age *
#     Owns.Property + Demographics * Owns.Property + Gender * Platform +
#     Age * Platform, data = bootstrapped_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.983  -4.242   0.190   4.222   9.907
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                1.386e+01  3.367e-01  41.159
# Income                                    -5.721e-05  7.714e-06  -7.417
# DebtTRUE                                   4.649e+00  3.567e-01  13.034
# Owns.PropertyTRUE                          6.152e-01  2.008e-01   3.064
# DeviceTypeSmartphone                       6.717e-01  5.226e-02  12.852
# DeviceTypeTablet                           3.347e-01  5.670e-02   5.904
# PlatformInstagram                         -5.047e+00  1.740e-01 -29.009
# PlatformTikTok                            -2.492e+00  1.711e-01 -14.562
# PlatformYouTube                           -3.289e+00  1.720e-01 -19.119
# DemographicsUrban                          1.734e+00  1.312e-01  13.221
# Age                                       -1.093e-01  4.968e-03 -22.011
# GenderMale                                -2.693e+00  1.933e-01 -13.934
# GenderOther                               -4.364e+00  2.555e-01 -17.080
# ProfessionCashier                         -8.372e-01  3.659e-01  -2.288
# Professiondriver                           2.387e+00  3.012e-01   7.925
# ProfessionEngineer                        -2.352e+00  3.749e-01  -6.272
# ProfessionLabor/Worker                     2.539e-01  2.866e-01   0.886
# ProfessionManager                          2.546e+00  3.873e-01   6.576
# ProfessionStudents                         7.276e-02  2.813e-01   0.259
# ProfessionTeacher                         -5.490e+00  4.419e-01 -12.423
# ProfessionWaiting staff                    1.458e+00  2.845e-01   5.124
# GenderMale:ProfessionCashier               5.304e+00  2.412e-01  21.988
# GenderOther:ProfessionCashier              2.666e+00  3.128e-01   8.522
# GenderMale:Professiondriver                3.481e-02  2.085e-01   0.167
# GenderOther:Professiondriver               1.905e+00  2.725e-01   6.988
# GenderMale:ProfessionEngineer              1.587e+00  2.280e-01   6.960
# GenderOther:ProfessionEngineer             1.442e+00  3.338e-01   4.320
# GenderMale:ProfessionLabor/Worker          1.445e+00  1.961e-01   7.369
# GenderOther:ProfessionLabor/Worker         1.487e+00  2.560e-01   5.808
# GenderMale:ProfessionManager               3.213e-01  2.606e-01   1.233
# GenderOther:ProfessionManager             -7.837e-01  3.240e-01  -2.419
# GenderMale:ProfessionStudents              1.360e+00  1.922e-01   7.078
# GenderOther:ProfessionStudents             1.412e+00  2.547e-01   5.542
# GenderMale:ProfessionTeacher               1.267e+00  2.587e-01   4.898
# GenderOther:ProfessionTeacher              1.106e+00  3.327e-01   3.323
# GenderMale:ProfessionWaiting staff         6.535e-01  1.949e-01   3.354
# GenderOther:ProfessionWaiting staff        3.710e-01  2.575e-01   1.441
# Income:ProfessionCashier                  -6.166e-06  8.940e-06  -0.690
# Income:Professiondriver                   -1.287e-05  7.486e-06  -1.719
# Income:ProfessionEngineer                  1.313e-04  8.906e-06  14.737
# Income:ProfessionLabor/Worker              4.969e-05  7.217e-06   6.884
# Income:ProfessionManager                  -1.788e-05  9.134e-06  -1.957
# Income:ProfessionStudents                  3.632e-05  7.084e-06   5.127
# Income:ProfessionTeacher                   1.652e-04  1.008e-05  16.383
# Income:ProfessionWaiting staff             2.756e-05  7.171e-06   3.843
# Income:Age                                 8.275e-07  1.000e-07   8.272
# Income:DemographicsUrban                  -1.847e-05  3.156e-06  -5.852
# DebtTRUE:ProfessionCashier                -4.862e+00  4.056e-01 -11.987
# DebtTRUE:Professiondriver                 -2.233e+00  3.513e-01  -6.356
# DebtTRUE:ProfessionEngineer               -7.686e+00  4.194e-01 -18.327
# DebtTRUE:ProfessionLabor/Worker           -5.846e+00  3.390e-01 -17.242
# DebtTRUE:ProfessionManager                -1.789e+00  4.553e-01  -3.928
# DebtTRUE:ProfessionStudents               -5.005e+00  3.285e-01 -15.237
# DebtTRUE:ProfessionTeacher                -9.589e+00  4.811e-01 -19.932
# DebtTRUE:ProfessionWaiting staff          -3.578e+00  3.362e-01 -10.643
# DebtTRUE:Age                              -8.858e-03  4.821e-03  -1.837
# DebtTRUE:DemographicsUrban                -7.726e-01  1.528e-01  -5.058
# Owns.PropertyTRUE:ProfessionCashier       -4.533e-01  2.282e-01  -1.987
# Owns.PropertyTRUE:Professiondriver        -2.277e+00  1.954e-01 -11.649
# Owns.PropertyTRUE:ProfessionEngineer      -4.004e+00  2.164e-01 -18.498
# Owns.PropertyTRUE:ProfessionLabor/Worker  -2.293e+00  1.835e-01 -12.500
# Owns.PropertyTRUE:ProfessionManager       -3.515e+00  2.234e-01 -15.734
# Owns.PropertyTRUE:ProfessionStudents      -9.631e-01  1.797e-01  -5.360
# Owns.PropertyTRUE:ProfessionTeacher       -1.174e-01  2.505e-01  -0.468
# Owns.PropertyTRUE:ProfessionWaiting staff -2.256e+00  1.834e-01 -12.301
# Owns.PropertyTRUE:Age                      3.800e-02  2.545e-03  14.932
# Owns.PropertyTRUE:DemographicsUrban        4.075e-01  7.855e-02   5.188
# PlatformInstagram:GenderMale               9.024e-01  1.090e-01   8.280
# PlatformTikTok:GenderMale                  3.423e-01  1.094e-01   3.129
# PlatformYouTube:GenderMale                 2.157e+00  1.118e-01  19.294
# PlatformInstagram:GenderOther              4.090e+00  1.571e-01  26.040
# PlatformTikTok:GenderOther                 1.347e+00  1.524e-01   8.837
# PlatformYouTube:GenderOther                4.631e+00  1.545e-01  29.981
# PlatformInstagram:Age                      1.019e-01  3.798e-03  26.814
# PlatformTikTok:Age                         5.553e-02  3.613e-03  15.369
# PlatformYouTube:Age                        3.791e-02  3.612e-03  10.496
#                                           Pr(>|t|)
# (Intercept)                                < 2e-16 ***
# Income                                    1.21e-13 ***
# DebtTRUE                                   < 2e-16 ***
# Owns.PropertyTRUE                         0.002187 **
# DeviceTypeSmartphone                       < 2e-16 ***
# DeviceTypeTablet                          3.56e-09 ***
# PlatformInstagram                          < 2e-16 ***
# PlatformTikTok                             < 2e-16 ***
# PlatformYouTube                            < 2e-16 ***
# DemographicsUrban                          < 2e-16 ***
# Age                                        < 2e-16 ***
# GenderMale                                 < 2e-16 ***
# GenderOther                                < 2e-16 ***
# ProfessionCashier                         0.022146 *
# Professiondriver                          2.30e-15 ***
# ProfessionEngineer                        3.59e-10 ***
# ProfessionLabor/Worker                    0.375693
# ProfessionManager                         4.87e-11 ***
# ProfessionStudents                        0.795898
# ProfessionTeacher                          < 2e-16 ***
# ProfessionWaiting staff                   3.00e-07 ***
# GenderMale:ProfessionCashier               < 2e-16 ***
# GenderOther:ProfessionCashier              < 2e-16 ***
# GenderMale:Professiondriver               0.867410
# GenderOther:Professiondriver              2.80e-12 ***
# GenderMale:ProfessionEngineer             3.42e-12 ***
# GenderOther:ProfessionEngineer            1.56e-05 ***
# GenderMale:ProfessionLabor/Worker         1.73e-13 ***
# GenderOther:ProfessionLabor/Worker        6.35e-09 ***
# GenderMale:ProfessionManager              0.217654
# GenderOther:ProfessionManager             0.015563 *
# GenderMale:ProfessionStudents             1.47e-12 ***
# GenderOther:ProfessionStudents            2.99e-08 ***
# GenderMale:ProfessionTeacher              9.71e-07 ***
# GenderOther:ProfessionTeacher             0.000890 ***
# GenderMale:ProfessionWaiting staff        0.000797 ***
# GenderOther:ProfessionWaiting staff       0.149597
# Income:ProfessionCashier                  0.490397
# Income:Professiondriver                   0.085646 .
# Income:ProfessionEngineer                  < 2e-16 ***
# Income:ProfessionLabor/Worker             5.85e-12 ***
# Income:ProfessionManager                  0.050300 .
# Income:ProfessionStudents                 2.95e-07 ***
# Income:ProfessionTeacher                   < 2e-16 ***
# Income:ProfessionWaiting staff            0.000122 ***
# Income:Age                                 < 2e-16 ***
# Income:DemographicsUrban                  4.86e-09 ***
# DebtTRUE:ProfessionCashier                 < 2e-16 ***
# DebtTRUE:Professiondriver                 2.07e-10 ***
# DebtTRUE:ProfessionEngineer                < 2e-16 ***
# DebtTRUE:ProfessionLabor/Worker            < 2e-16 ***
# DebtTRUE:ProfessionManager                8.56e-05 ***
# DebtTRUE:ProfessionStudents                < 2e-16 ***
# DebtTRUE:ProfessionTeacher                 < 2e-16 ***
# DebtTRUE:ProfessionWaiting staff           < 2e-16 ***
# DebtTRUE:Age                              0.066139 .
# DebtTRUE:DemographicsUrban                4.25e-07 ***
# Owns.PropertyTRUE:ProfessionCashier       0.046973 *
# Owns.PropertyTRUE:Professiondriver         < 2e-16 ***
# Owns.PropertyTRUE:ProfessionEngineer       < 2e-16 ***
# Owns.PropertyTRUE:ProfessionLabor/Worker   < 2e-16 ***
# Owns.PropertyTRUE:ProfessionManager        < 2e-16 ***
# Owns.PropertyTRUE:ProfessionStudents      8.36e-08 ***
# Owns.PropertyTRUE:ProfessionTeacher       0.639484
# Owns.PropertyTRUE:ProfessionWaiting staff  < 2e-16 ***
# Owns.PropertyTRUE:Age                      < 2e-16 ***
# Owns.PropertyTRUE:DemographicsUrban       2.13e-07 ***
# PlatformInstagram:GenderMale               < 2e-16 ***
# PlatformTikTok:GenderMale                 0.001752 **
# PlatformYouTube:GenderMale                 < 2e-16 ***
# PlatformInstagram:GenderOther              < 2e-16 ***
# PlatformTikTok:GenderOther                 < 2e-16 ***
# PlatformYouTube:GenderOther                < 2e-16 ***
# PlatformInstagram:Age                      < 2e-16 ***
# PlatformTikTok:Age                         < 2e-16 ***
# PlatformYouTube:Age                        < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.189 on 99924 degrees of freedom
# Multiple R-squared:  0.07132,	Adjusted R-squared:  0.07062
# F-statistic: 102.3 on 75 and 99924 DF,  p-value: < 2.2e-16

# %%
vif_values_2 <- vif(ols_model_2, type = 'predictor')
print(vif_values_2)
# Out:
# GVIFs computed for predictors
#                       GVIF Df GVIF^(1/(2*Df))
# Income        2.736811e+14 21        2.206703
# Debt          1.223465e+17 21        2.551805
# Owns.Property 4.707965e+11 21        1.896377
# DeviceType    1.177746e+00  2        1.041748
# Platform      1.256599e+04 15        1.369746
# Demographics  5.262449e+04  7        2.173841
# Age           7.330192e+05 13        1.681053
# Gender        1.644534e+12 35        1.494565
# Profession    8.677171e+04 53        1.113239
#                                      Interacts With
# Income                Profession, Age, Demographics
# Debt                  Profession, Age, Demographics
# Owns.Property         Profession, Age, Demographics
# DeviceType                                     --
# Platform                                Gender, Age
# Demographics            Income, Debt, Owns.Property
# Age           Income, Debt, Owns.Property, Platform
# Gender                         Profession, Platform
# Profession      Gender, Income, Debt, Owns.Property
#                                                                           Other Predictors
# Income                                   Debt, Owns.Property, DeviceType, Platform, Gender
# Debt                                   Income, Owns.Property, DeviceType, Platform, Gender
# Owns.Property                                   Income, Debt, DeviceType, Platform, Gender
# DeviceType    Income, Debt, Owns.Property, Platform, Demographics, Age, Gender, Profession
# Platform                 Income, Debt, Owns.Property, DeviceType, Demographics, Profession
# Demographics                                 DeviceType, Platform, Age, Gender, Profession
# Age                                           DeviceType, Demographics, Gender, Profession
# Gender                          Income, Debt, Owns.Property, DeviceType, Demographics, Age
# Profession                                         DeviceType, Platform, Demographics, Age

# %%
#Check residuals
fitted_values_2 <- fitted(ols_model_2)
residuals_2 <- resid(ols_model_2)

plot(fitted_values_2, residuals_2,
     main = "Residuals vs Fitted Values",
     xlab = "Fitted Values",
     ylab = "Residuals",
     pch = 19, col = "blue")

abline(h = 0, col = "red", lty = 2)
# Out:
# Plot with title “Residuals vs Fitted Values”

# %%
#To check for heteroskedasticity
white_test_2 <- white(ols_model)
white_test_2
# Out:
#   statistic p.value   parameter method       alternative
# 1 93.69672  0.9999078 150       White's Test greater

# %% [markdown]
# The White Test confirms that the homoskedasticity assumption is met i.e. the disturbance term is homoskedastic.

# %% [markdown]
# ### Limitations/ Directions for Follow-Up Research:
# * Missing variables/ Potential Omitted variable Bias(OVB): Depression, Anxiety, Stress, Education, Self-Esteem, Personality Traits, etc. which have also been found to correlate with social media usage.
# * This analysis does not take into consideration complex psychological factors that may lead to social media addiction such as salience, mood modification, relapse, withdrawal, and conflict, etc. Similarly, we have not taken into consideration the specific mechanism behind the relationships between other predictors and social media usage. For example, sociocultural factors and how they may predict rural vs urban attitudes towards social media.

# %% [markdown]
# ### References:
#
# Alblwi, A., McAlaney, J., Al Thani, D.A.S. et al. Procrastination on social media: predictors of types, triggers and acceptance of countermeasures. Soc. Netw. Anal. Min. 11, 19 (2021). https://doi.org/10.1007/s13278-021-00727-1
#
# Amanda Baughan, Mingrui Ray Zhang, Raveena Rao, Kai Lukoff, Anastasia Schaadhardt, Lisa D. Butler, and Alexis Hiniker. 2022. “I Don’t Even Remember What I Read”: How Design Influences Dissociation on Social Media. In Proceedings of the 2022 CHI Conference on Human Factors in Computing Systems (CHI '22). Association for Computing Machinery, New York, NY, USA, Article 18, 1–13. https://doi.org/10.1145/3491102.3501899
#
# Arguedas, A., Robertson, C. T., Fletcher, R., & Nielsen, R. K. (2022, January 19). Echo chambers, filter bubbles, and polarisation: a literature review. Reuters Institute for the Study of Journalism. https://reutersinstitute.politics.ox.ac.uk/echo-chambers-filter-bubbles-and-polarisation-literature-review#header--8
#
# Baerg MacDonald, K., Benson, A., Sakaluk, J. K., & Schermer, J. A. (2023). Pre-Occupation: A Meta-Analysis and Meta-Regression of Gender Differences in Adolescent Vocational Interests. Journal of Career Assessment, 31(4), 715-738. https://doi.org/10.1177/10690727221148717
#
# Copeland, C. (2022, March 3). Understanding the Finances of Rural vs. Urban Americans. Employee Benefit Research Institute. https://www.ebri.org/content/understanding-the-finances-of-rural-vs.-urban-americans
#
# Cunningham, S., Hudson, C.C. & Harkness, K. Social Media and Depression Symptoms: a Meta-Analysis. Res Child Adolesc Psychopathol 49, 241–253 (2021). https://doi-org.libproxy.berkeley.edu/10.1007/s10802-020-00715-7
#
# González-Bueso V, Santamaría JJ, Fernández D, Merino L, Montero E, Ribas J. Association between Internet Gaming Disorder or Pathological Video-Game Use and Comorbid Psychopathology: A Comprehensive Review. Int J Environ Res Public Health. 2018 Apr 3;15(4):668. doi: 10.3390/ijerph15040668. PMID: 29614059; PMCID: PMC5923710.
#
# Hale, T. M., Cotten, S. R., Drentea, P., & Goldner, M. (2010). Rural-Urban Differences in General and Health-Related Internet Use. American Behavioral Scientist, 53(9), 1304-1325. https://doi.org/10.1177/0002764210361685
#
# Hruska, J., & Maresova, P. (2020). Use of Social Media Platforms among Adults in the United States—Behavior on Social Media. Societies, 10(1), 27. https://doi.org/10.3390/soc10010027
#
# Li, S., Ren, P., Chiu, M. M., Wang, C., & Lei, H. (2021). The Relationship Between Self-Control and Internet Addiction Among Students: A Meta-Analysis. Frontiers in Psychology, 12. https://doi.org/10.3389/fpsyg.2021.735755
#
# McCabe, S.D., Ferrari, D., Green, J. et al. Post-January 6th deplatforming reduced the reach of misinformation on Twitter. Nature 630, 132–140 (2024). https://doi.org/10.1038/s41586-024-07524-8
#
# Moon, Y. E., & Lewis, S. C. (2024). Social Media as Commodifier or Homogenizer? Journalists’ Social Media Use in Individualistic and Collectivist Cultures and Its Implications for Epistemologies of News Production. Digital Journalism, 1–20. https://doi.org/10.1080/21670811.2024.2303988
#
# Patti Valkenburg, Ine Beyens, J Loes Pouwels, Irene I van Driel, Loes Keijsers, Social Media Use and Adolescents’ Self-Esteem: Heading for a Person-Specific Media Effects Paradigm, Journal of Communication, Volume 71, Issue 1, February 2021, Pages 56–78, https://doi.org/10.1093/joc/jqaa039
#
# Peng, P., Liao, Y. Six addiction components of problematic social media use in relation to depression, anxiety, and stress symptoms: a latent profile analysis and network analysis. BMC Psychiatry 23, 321 (2023). https://doi.org/10.1186/s12888-023-04837-2
#
# Purba A K, Thomson R M, Henery P M, Pearce A, Henderson M, Katikireddi S V et al. Social media use and health risk behaviours in young people: systematic review and meta-analysis BMJ 2023; 383 :e073552 doi:10.1136/bmj-2022-073552
#
# Social Media and News Fact Sheet. (2024, September 17). Pew Research Center. https://www.pewresearch.org/journalism/fact-sheet/social-media-and-news-fact-sheet/
#
# Social Media Users by Country 2024. (n.d.). World Population by Country 2024 (Live). https://worldpopulationreview.com/country-rankings/social-media-users-by-country
#
# Vaid, S. S., & Harari, G. M. (2020). Who Uses What and How Often?: Personality Predictors of Multiplatform Social Media Use Among Young Adults. Journal of Research in Personality, 104005. https://doi.org/10.1016/j.jrp.2020.104005
#
# Walkley, S. (2023, March). The Carbon Cost of Social Media - The Carbon Literacy Project. The Carbon Literacy Project. https://carbonliteracy.com/the-carbon-cost-of-social-media/
