# %%
install.packages("ggdag")
# Out:
# Installing package into ‘/srv/r’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘V8’, ‘dagitty’

# %%
library(ggdag)
library(ggplot2)
# Out:
# Attaching package: ‘ggdag’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
dag <- dagitty::dagitty("dag {
    y <- x <- z1 <- v -> z2 -> y
    z1 <- w1 <-> w2 -> z2
    x <- w1 -> y
    x <- w2 -> y
    x [exposure]
    y [outcome]
  }")

# %%
tidy_dag <- tidy_dagitty(dag)

tidy_dag
# Out:
# # A DAG with 7 nodes and 12 edges
# #
# # Exposure: x
# # Outcome: y
# #
# # A tibble: 13 × 8
#    name      x     y direction to     xend  yend circular
#    <chr> <dbl> <dbl> <fct>     <chr> <dbl> <dbl> <lgl>
#  1 v     -2.77 -3.61 ->        z1    -1.94 -2.46 FALSE
#  2 v     -2.77 -3.61 ->        z2    -3.93 -2.80 FALSE
#  3 w1    -2.59 -1.10 ->        x     -2.61 -1.73 FALSE
#  4 w1    -2.59 -1.10 ->        y     -3.75 -1.30 FALSE
#  5 w1    -2.59 -1.10 ->        z1    -1.94 -2.46 FALSE
#  6 w1    -2.59 -1.10 <->       w2    -3.53 -1.89 FALSE
#  7 w2    -3.53 -1.89 ->        x     -2.61 -1.73 FALSE
#  8 w2    -3.53 -1.89 ->        y     -3.75 -1.30 FALSE
#  9 w2    -3.53 -1.89 ->        z2    -3.93 -2.80 FALSE
# 10 x     -2.61 -1.73 ->        y     -3.75 -1.30 FALSE
# 11 y     -3.75 -1.30 NA        NA    NA    NA    FALSE
# 12 z1    -1.94 -2.46 ->        x     -2.61 -1.73 FALSE
# 13 z2    -3.93 -2.80 ->        y     -3.75 -1.30 FALSE

# %%
tidy_ggdag <- dagify(
  y ~ x + z2 + w2 + w1,
  x ~ z1 + w1 + w2,
  z1 ~ w1 + v,
  z2 ~ w2 + v,
  w1 ~ ~w2, # bidirected path
  exposure = "x",
  outcome = "y"
) %>%
  tidy_dagitty()

tidy_ggdag
# Out:
# # A DAG with 7 nodes and 12 edges
# #
# # Exposure: x
# # Outcome: y
# #
# # A tibble: 13 × 8
#    name      x     y direction to     xend   yend circular
#    <chr> <dbl> <dbl> <fct>     <chr> <dbl>  <dbl> <lgl>
#  1 v      3.84 1.02  ->        z1     3.10  2.23  FALSE
#  2 v      3.84 1.02  ->        z2     2.65  0.297 FALSE
#  3 w1     1.55 2.14  ->        x      2.16  2.08  FALSE
#  4 w1     1.55 2.14  ->        y      1.38  1.03  FALSE
#  5 w1     1.55 2.14  ->        z1     3.10  2.23  FALSE
#  6 w1     1.55 2.14  <->       w2     2.02  1.11  FALSE
#  7 w2     2.02 1.11  ->        x      2.16  2.08  FALSE
#  8 w2     2.02 1.11  ->        y      1.38  1.03  FALSE
#  9 w2     2.02 1.11  ->        z2     2.65  0.297 FALSE
# 10 x      2.16 2.08  ->        y      1.38  1.03  FALSE
# 11 y      1.38 1.03  NA        NA    NA    NA     FALSE
# 12 z1     3.10 2.23  ->        x      2.16  2.08  FALSE
# 13 z2     2.65 0.297 ->        y      1.38  1.03  FALSE

# %%
ggdag(tidy_ggdag) +
  theme_dag()
# Out:
# plot without title

# %%
platform type ~ age + gender
